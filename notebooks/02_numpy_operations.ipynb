# %% [markdown]
# # py-iku: NumPy Operations Support
#
# This notebook demonstrates how py-iku converts NumPy operations to Dataiku DSS recipes and processors.
#
# ## Supported NumPy Operations
#
# py-iku supports 30+ NumPy functions across these categories:
# - Mathematical: log, exp, sqrt, power, abs, round
# - Conditional: where, isnan, isinf, isfinite
# - Aggregations: sum, mean, std, var, min, max, median
# - Array operations: concatenate, vstack, hstack, sort, unique

# %%
from py2dataiku import convert
from py2dataiku.parser.ast_analyzer import CodeAnalyzer

# %% [markdown]
# ## 1. Mathematical Transformations
#
# NumPy math functions are converted to Dataiku Prepare recipe steps with formula processors.

# %%
math_code = '''
import numpy as np
import pandas as pd

df = pd.read_csv('metrics.csv')

# Logarithmic transformations
df['log_value'] = np.log(df['value'])
df['log10_value'] = np.log10(df['value'])
df['log1p_value'] = np.log1p(df['value'])  # log(1 + x)

# Exponential
df['exp_rate'] = np.exp(df['rate'])

# Power functions
df['sqrt_value'] = np.sqrt(df['value'])
df['squared'] = np.power(df['value'], 2)
df['cubed'] = np.power(df['value'], 3)

df.to_csv('transformed_metrics.csv', index=False)
'''

# Analyze the transformations
analyzer = CodeAnalyzer()
transformations = analyzer.analyze(math_code)

print("Detected Transformations:")
for t in transformations:
    print(f"  - {t.transformation_type.value}: {t.parameters}")
# Out:
# Detected Transformations:
#   - read_data: {'filepath': 'metrics.csv', 'format': 'csv'}
#   - numeric_transform: {'operation': 'NATURAL_LOG'}
#   - numeric_transform: {'operation': 'LOG10'}
#   - numeric_transform: {'operation': 'LOG1P'}
#   - numeric_transform: {'operation': 'EXP'}
#   - numeric_transform: {'operation': 'SQRT', 'exponent': None}
#   - numeric_transform: {'operation': 'POWER', 'exponent': 2}
#   - numeric_transform: {'operation': 'POWER', 'exponent': 3}
#   - write_data: {'filepath': 'transformed_metrics.csv'}

# %%
# Convert to flow
flow = convert(math_code)
print(flow.get_summary())
# Out:
# Flow: converted_flow
# Source: unknown
# Generated: 2026-04-25T10:31:07.059818
#
# Datasets: 2
#   - Input: 0
#   - Intermediate: 1
#   - Output: 1
#
# Recipes: 7
#   - prepare: 7
#
# Optimization Notes:
#   - prepare: 7 recipe(s)
#   - Flow contains 7 Prepare recipes

# %% [markdown]
# ### SVG Visualization of Math Transformations
#
# Render the math transformations flow as an SVG diagram showing datasets and Prepare recipe steps.

# %%
# SVG visualization of the math transformations flow
from IPython.display import SVG, display

svg_output = flow.visualize(format='svg')
display(SVG(svg_output))

# %% [markdown]
# ### PNG Export (Matplotlib)
#
# The `MatplotlibVisualizer` produces polished PNG diagrams with DDODS-inspired styling — semantic colors, rounded nodes, and flow zone backgrounds.

# %%
# PNG export - publication-quality diagram
from py2dataiku.visualizers import MatplotlibVisualizer
from IPython.display import Image, display

viz = MatplotlibVisualizer()
png_bytes = viz.render(flow)
display(Image(png_bytes))

# %% [markdown]
# ## 2. Rounding and Clipping
#
# NumPy's rounding and clipping functions map to Dataiku's ROUND_COLUMN and CLIP_COLUMN processors.

# %%
round_clip_code = '''
import numpy as np
import pandas as pd

df = pd.read_csv('scores.csv')

# Rounding operations
df['score_rounded'] = np.round(df['score'], 2)
df['score_floor'] = np.floor(df['score'])
df['score_ceil'] = np.ceil(df['score'])

# Clipping (constraining values)
df['score_clipped'] = np.clip(df['score'], 0, 100)  # Between 0 and 100
df['positive_only'] = np.clip(df['value'], 0, None)  # Minimum 0

# Absolute value
df['abs_diff'] = np.abs(df['actual'] - df['predicted'])

df.to_csv('processed_scores.csv', index=False)
'''

flow = convert(round_clip_code)
print(flow.visualize(format='ascii'))
# Out:
# ════════════════════════════════════════════════════════════════════════════════
#                           DATAIKU FLOW: converted_flow
# ════════════════════════════════════════════════════════════════════════════════
#
#                               ┌──────────────────┐
#                               │ 📊 df             │
#                              │    [OUTPUT]       │
#                               └──────────────────┘
#
#                                        │
#                                        ▼
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                        │
#                                        ▼
#
#                               ┌──────────────────┐
#                               │ 📊 df_prepared    │
#                               └──────────────────┘
#
# ════════════════════════════════════════════════════════════════════════════════
#
# Legend: 📊 Dataset  ⚙ Prepare  ⋈ Join  Σ Grouping  ⑂ Split  ⇅ Sort

# %% [markdown]
# ### Mermaid Diagram of Rounding/Clipping Flow
#
# The same flow rendered as a Mermaid diagram, suitable for embedding in GitHub README or documentation.

# %%
# Mermaid diagram output for the rounding/clipping flow
mermaid_output = flow.visualize(format='mermaid')
print(mermaid_output)
# Out:
# flowchart TD
#     subgraph outputs[Output Datasets]
#         D0[(df)]
#     end
#     D1[(df_prepared)]
#     R0{Prepare\n(1 steps)}
#     R1{Prepare\n(1 steps)}
#     R2{Prepare\n(1 steps)}
#     R3{Prepare\n(1 steps)}
#     R4{Prepare\n(1 steps)}
#     D0 --> R0
#     R0 --> D1
#     D0 --> R1
#     R1 --> D1
#     D0 --> R2
#     R2 --> D1
#     D0 --> R3
#     R3 --> D1
#     D0 --> R4
#     R4 --> D1
#
#     style D0 fill:#c8e6c9
#     style R0 fill:#fff3e0
#     style R1 fill:#fff3e0
#     style R2 fill:#fff3e0
#     style R3 fill:#fff3e0
#     style R4 fill:#fff3e0

# %% [markdown]
# ## 3. Conditional Operations
#
# `np.where()` is converted to Dataiku's formula-based column creation with if/else logic.

# %%
conditional_code = '''
import numpy as np
import pandas as pd

df = pd.read_csv('transactions.csv')

# Conditional column creation with np.where
df['category'] = np.where(df['amount'] > 1000, 'high_value', 'standard')
df['is_positive'] = np.where(df['balance'] > 0, 'positive', 'negative')

# NaN checking
df['has_missing'] = np.isnan(df['optional_field'])
df['is_valid'] = np.isfinite(df['ratio'])

# Replace NaN values
df['cleaned_ratio'] = np.nan_to_num(df['ratio'], nan=0.0)

df.to_csv('categorized_transactions.csv', index=False)
'''

# Analyze
analyzer = CodeAnalyzer()
transformations = analyzer.analyze(conditional_code)

print("Conditional Transformations:")
for t in transformations:
    if 'where' in str(t.notes).lower() or 'is' in str(t.parameters).lower():
        print(f"  - {t.transformation_type.value}")
        print(f"    Parameters: {t.parameters}")
        print(f"    Notes: {t.notes}")
# Out:
# Conditional Transformations:
#   - column_create
#     Parameters: {'condition': '', 'if_true': '', 'if_false': ''}
#     Notes: ['np.where() -> Prepare recipe with if/else formula']
#   - column_create
#     Parameters: {'condition': '', 'if_true': '', 'if_false': ''}
#     Notes: ['np.where() -> Prepare recipe with if/else formula']
#   - column_create
#     Parameters: {'check_type': 'IS_NAN'}
#     Notes: ['np.isnan() -> Prepare recipe FlagOnValue processor']
#   - column_create
#     Parameters: {'check_type': 'IS_FINITE'}
#     Notes: ['np.isfinite() -> Prepare recipe FlagOnValue processor']

# %% [markdown]
# ## 4. Aggregation Functions
#
# NumPy aggregations are detected and can inform Grouping recipe creation.

# %%
agg_code = '''
import numpy as np
import pandas as pd

df = pd.read_csv('sales.csv')

# Calculate statistics using NumPy
total_sales = np.sum(df['amount'])
avg_sale = np.mean(df['amount'])
std_sale = np.std(df['amount'])
median_sale = np.median(df['amount'])

# Percentiles
p25 = np.percentile(df['amount'], 25)
p75 = np.percentile(df['amount'], 75)
p90 = np.percentile(df['amount'], 90)

# Min/Max
min_sale = np.min(df['amount'])
max_sale = np.max(df['amount'])

print(f"Statistics computed")
'''

flow = convert(agg_code)
print(flow.get_summary())
# Out:
# Flow: converted_flow
# Source: unknown
# Generated: 2026-04-25T10:31:07.382859
#
# Datasets: 10
#   - Input: 1
#   - Intermediate: 9
#   - Output: 0
#
# Recipes: 9
#   - grouping: 9
#
# Optimization Notes:
#   - grouping: 9 recipe(s)

# %% [markdown]
# ## 5. Feature Engineering Pipeline
#
# A complete feature engineering pipeline combining NumPy and pandas.

# %%
feature_code = '''
import numpy as np
import pandas as pd

df = pd.read_csv('raw_features.csv')

# Log transform skewed features
df['log_income'] = np.log1p(df['income'])
df['log_transactions'] = np.log1p(df['num_transactions'])

# Normalize features
df['income_normalized'] = (df['income'] - np.mean(df['income'])) / np.std(df['income'])

# Clip outliers
df['income_clipped'] = np.clip(df['income'], 
                                np.percentile(df['income'], 1),
                                np.percentile(df['income'], 99))

# Handle special values
df['ratio_clean'] = np.nan_to_num(df['ratio'], nan=0, posinf=1, neginf=-1)
df['is_valid'] = np.isfinite(df['score']).astype(int)

# Create categorical flags
df['high_income'] = np.where(df['income'] > 100000, 1, 0)
df['active_user'] = np.where(df['num_transactions'] > 10, 1, 0)

# Save engineered features
df.to_csv('engineered_features.csv', index=False)
'''

flow = convert(feature_code)
print("Feature Engineering Flow:")
print(flow.visualize(format='ascii'))
# Out:
# Feature Engineering Flow:
# ════════════════════════════════════════════════════════════════════════════════
#                           DATAIKU FLOW: converted_flow
# ════════════════════════════════════════════════════════════════════════════════
#
#                                 ┌──────────────┐
#                                │   λ PYTHON    │
#                                 │ ──────────── │
#                                 └──────────────┘
#
#                               ┌──────────────────┐
#                               │ 📊 df             │
#                              │    [OUTPUT]       │
#                               └──────────────────┘
#
#                                        │
#                                        ▼
#
#                               ┌──────────────────┐
#                               │ 📊 _chain_step_0  │
#                               └──────────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                                        │
#                                        ▼
#
#                                 ┌──────────────┐
#                                │   ⚙ PREPARE   │
#                                 │ ──────────── │
#                                 │ 1 steps      │
#                                 └──────────────┘
#
#                               ┌──────────────────┐
#                               │ 📊 df_prepared    │
#                               └──────────────────┘
#
#                                        │
#                                        ▼
#
#                           ┌──────────────────────────┐
#                           │ 📊 _chain_step_0_prepared │
#                           └──────────────────────────┘
#
# ════════════════════════════════════════════════════════════════════════════════
#
# Legend: 📊 Dataset  ⚙ Prepare  ⋈ Join  Σ Grouping  ⑂ Split  ⇅ Sort

# %% [markdown]
# ### SVG Visualization and DAG Analysis
#
# Visualize the feature engineering pipeline as an SVG diagram and analyze the flow's DAG structure.

# %%
# SVG visualization of the feature engineering pipeline
from IPython.display import SVG, display

display(SVG(flow.visualize(format='svg')))

# DAG analysis of the feature engineering flow
graph = flow.graph
print("\nFlow Graph Analysis:")
print(f"  Topological order: {graph.topological_sort()}")
print(f"  Root nodes (inputs): {graph.get_roots()}")
print(f"  Leaf nodes (outputs): {graph.get_leaves()}")
print(f"  Cycles detected: {graph.detect_cycles()}")
print(f"  Total recipes: {len(flow.recipes)}")
print(f"  Total datasets: {len(flow.datasets)}")
# Out:
# Flow Graph Analysis:
#   Topological order: ['df', 'recipe:python_5', 'recipe:prepare_1', 'recipe:prepare_2', 'recipe:prepare_3', 'recipe:prepare_4', '_chain_step_0', 'df_prepared', 'recipe:prepare_6', '_chain_step_0_prepared']
#   Root nodes (inputs): ['df', 'recipe:python_5']
#   Leaf nodes (outputs): ['df_prepared', '_chain_step_0_prepared']
#   Cycles detected: []
#   Total recipes: 6
#   Total datasets: 4

# %% [markdown]
# ### Theme Comparison: Light vs Dark
#
# py-iku supports Dataiku-styled themes. Compare the feature engineering flow in light and dark modes.

# %%
# Compare light and dark themes
from py2dataiku import DATAIKU_LIGHT, DATAIKU_DARK
from IPython.display import SVG, display, HTML

display(HTML("<h4>Light Theme</h4>"))
display(SVG(flow.visualize(format='svg', theme=DATAIKU_LIGHT)))

display(HTML("<h4>Dark Theme</h4>"))
display(SVG(flow.visualize(format='svg', theme=DATAIKU_DARK)))
# Out:
# <h4>Light Theme</h4>
# <h4>Dark Theme</h4>

# %% [markdown]
# ## 6. Array Operations
#
# NumPy array operations like concatenate and unique are also supported.

# %%
array_code = '''
import numpy as np
import pandas as pd

# Load multiple datasets
df1 = pd.read_csv('data_2022.csv')
df2 = pd.read_csv('data_2023.csv')

# Vertical stack (concatenate)
combined = np.vstack([df1.values, df2.values])

# Get unique values
unique_categories = np.unique(df1['category'].values)

# Sort array
sorted_values = np.sort(df1['value'].values)

print("Array operations complete")
'''

analyzer = CodeAnalyzer()
transformations = analyzer.analyze(array_code)

print("Array Operations Detected:")
for t in transformations:
    print(f"  - {t.transformation_type.value}: {t.notes}")
# Out:
# Array Operations Detected:
#   - read_data: []
#   - read_data: []
#   - concat: ['np.vstack() -> Stack recipe']
#   - drop_duplicates: ['np.unique() -> Distinct recipe']
#   - sort: ['np.sort() -> Sort recipe']

# %% [markdown]
# ## 7. Supported NumPy Functions Reference
#
# Here's a complete list of supported NumPy functions:

# %%
numpy_functions = {
    "Mathematical": [
        "np.log", "np.log10", "np.log2", "np.log1p",
        "np.exp", "np.expm1",
        "np.sqrt", "np.cbrt", "np.square", "np.power",
        "np.abs", "np.absolute"
    ],
    "Rounding": [
        "np.round", "np.around", "np.rint",
        "np.floor", "np.ceil", "np.trunc"
    ],
    "Clipping": ["np.clip"],
    "Conditional": [
        "np.where",
        "np.isnan", "np.isinf", "np.isfinite",
        "np.nan_to_num", "np.nanmean", "np.nansum", "np.nanstd"
    ],
    "Aggregation": [
        "np.sum", "np.mean", "np.std", "np.var",
        "np.min", "np.max", "np.median",
        "np.percentile", "np.quantile"
    ],
    "Array Operations": [
        "np.concatenate", "np.vstack", "np.hstack", "np.stack",
        "np.sort", "np.argsort", "np.unique"
    ],
    "Reshaping": [
        "np.reshape", "np.flatten", "np.ravel", "np.transpose"
    ],
    "Creation": [
        "np.zeros", "np.ones", "np.full", "np.empty",
        "np.arange", "np.linspace"
    ]
}

for category, functions in numpy_functions.items():
    print(f"\n{category}:")
    for func in functions:
        print(f"  - {func}")
# Out:
# Mathematical:
#   - np.log
#   - np.log10
#   - np.log2
#   - np.log1p
#   - np.exp
#   - np.expm1
#   - np.sqrt
#   - np.cbrt
#   - np.square
#   - np.power
#   - np.abs
#   - np.absolute
#
# Rounding:
#   - np.round
#   - np.around
#   - np.rint
#   - np.floor
#   - np.ceil
#   - np.trunc
#
# Clipping:
#   - np.clip
#
# Conditional:
#   - np.where
#   - np.isnan
#   - np.isinf
#   - np.isfinite
#   - np.nan_to_num
#   - np.nanmean
#   - np.nansum
#   - np.nanstd
#
# Aggregation:
#   - np.sum
#   - np.mean
#   - np.std
#   - np.var
#   - np.min
#   - np.max
#   - np.median
#   - np.percentile
#   - np.quantile
#
# Array Operations:
#   - np.concatenate
#   - np.vstack
#   - np.hstack
#   - np.stack
#   - np.sort
#   - np.argsort
#   - np.unique
#
# Reshaping:
#   - np.reshape
#   - np.flatten
#   - np.ravel
#   - np.transpose
#
# Creation:
#   - np.zeros
#   - np.ones
#   - np.full
#   - np.empty
#   - np.arange
#   - np.linspace

# %% [markdown]
# ## Next Steps
#
# - See `03_sklearn_pipelines.ipynb` for scikit-learn ML pipeline support
# - See `04_visualizations.ipynb` for visualization options
